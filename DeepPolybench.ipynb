# %%
from pyllvm import *
import random
import re
import subprocess
import os
from  subprocess import call

from deap import base
from deap import creator
from deap import tools
from timeit import timeit
import time

import os.path, sys
# sys.path.append(os.path.join(os.path.dirname(os.path.realpath(__file__)), os.pardir))
# from dataset import *

# %%
# Generate CSmith code
def getPollyLLVM(polyfile):
    return getLLVM(polyfile, ["-I", 'benchmarks/polybench-c-3.2/utilities', '-include', 'benchmarks/polybench-c-3.2/utilities/polybench.c'])

def lsFiles(path="./deaptest"):
    path = os.path.abspath(path)
    p = re.compile("\d+.c")
    files = [f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f)) and p.match(f)]
    return files


usingopts = [
    'aa', 'adce', 'alignment-from-assumptions',
    'always-inline', 'argpromotion', 'assumption-cache-tracker',
    'atomic-expand', 'basicaa', 'basiccg', 'bdce',
    'block-freq', 'branch-prob', 'break-crit-edges',
    'cfinserter', 'cfl-anders-aa', 'cfl-steens-aa',
    'codegenprepare', 'consthoist', 'constmerge',
    'constprop', 'cost-model', 'cross-dso-cfi',
    'da', 'dce', 'deadargelim', 'delinearize',
    'demanded-bits', 'die', 'divergence', 'domfrontier',
    'domtree', 'dse', 'early-cse', 'early-cse-memssa',
    'elim-avail-extern', 'expand-reductions', 'external-aa',
    'flattencfg', 'float2int', 'forceattrs',
    'global-merge', 'globaldce', 'globalopt', 'globals-aa',
    'globalsplit', 'gvn', 'gvn-hoist', 'gvn-sink',
    'indvars', 'infer-address-spaces', 'inferattrs',
    'inline', 'instcombine', 'instsimplify', 'interleaved-access',
    'intervals', 'ipconstprop', 'ipsccp',
    'irce', 'iv-users', 'jump-threading', 'latesimplifycfg',
    'lcssa', 'libcalls-shrinkwrap', 'licm', 'load-store-vectorizer',
    'loop-accesses', 'loop-data-prefetch', 'loop-deletion',
    'loop-distribute', 'loop-extract', 'loop-extract-single',
    'loop-idiom', 'loop-instsimplify', 'loop-interchange',
    'loop-load-elim', 'loop-predication', 'loop-reduce', 'loop-reroll',
    'loop-rotate', 'loop-simplify', 'loop-simplifycfg', 'loop-sink',
    'loop-unroll', 'loop-unswitch', 'loop-vectorize', 'loop-versioning',
    'loop-versioning-licm', 'loops', 'lower-expect', 'lower-guard-intrinsic',
    'loweratomic', 'lowerinvoke', 'lowerswitch', 'lowertypetests',
    'machine-branch-prob', 'mem2reg', 'memcpyopt', 'memdep',
    'memoryssa', 'mergefunc', 'mergereturn', 'mldst-motion',
    'nary-reassociate', 'newgvn', 'opt-remark-emitter', 'pa-eval',
    'partial-inliner', 'partially-inline-libcalls',
    'place-backedge-safepoints-impl', 'place-safepoints',
    'postdomtree', 'pre-isel-intrinsic-lowering', 'prune-eh',
    'reassociate', 'reg2mem', 'regions', 'rewrite-statepoints-for-gc',
    'rpo-functionattrs', 'scalar-evolution', 'scalarize-masked-mem-intrin',
    'scalarizer', 'sccp', 'scev-aa', 'scoped-noalias', 'separate-const-offset-from-gep',
    'simple-loop-unswitch', 'simplifycfg', 'sink', 'slp-vectorizer', 'slsr',
    'speculative-execution', 'sroa', 'strip', 'strip-dead-debug-info',
    'strip-dead-prototypes', 'strip-debug-declare', 'strip-gc-relocates',
    'strip-nondebug', 'strip-nonlinetable-debuginfo', 'structurizecfg',
    'tailcallelim', 'targetlibinfo', 'tbaa', 'tti', 'unreachableblockelim',
    'wholeprogramdevirt'
]
# 'strip' is useful pass

def getRealOpts():
    opts = getOpts()
    omap = {o.getPassArgument():o for o in opts}
    opts = {a:omap[a] for a in usingopts} # if not omap[a].isAnalysis()}

    #for o in opts:
    #    if o.isAnalysis():
    #        print(o.getPassArgument(), o.getPassName())
    return opts

opts = getRealOpts()

def countPasses():
    count=len(opts)
    return count

def getTime(c_code, opt_indice):
    g = getPollyLLVM(c_code)

    llvm_opts = list(map((lambda x: opts[usingopts[x]]), opt_indice))
    for i, o in zip(opt_indice, llvm_opts):
        print("applying " + str(i)+"/"+str(len(opts)) + " " + o.getPassArgument() + " " + o.getPassName())
        applyOpt(o, g)
    #print(g)

    ## TODO run multiple times
    print("timing function")
    time = g.timeFunction("main", 1)
    print("wall time: ", time) 
    return time
    
def setupGA(c_code):
    # Weights=1 maximize a single objective
    creator.create("FitnessMax", base.Fitness, weights=(1.0,))
    creator.create("Individual", list, fitness=creator.FitnessMax)

    toolbox = base.Toolbox()

    # Attribute generator
    #                      define 'attr_bool' to be an attribute ('gene')
    #                      which corresponds to integers sampled uniformly
    #                      from the range [0,1] (i.e. 0 or 1 with equal
    #                      probability)
    toolbox.register("attr_bool", random.randint, 0, countPasses()-1)

    # Structure initializers
    #                         define 'individual' to be an individual
    #                         consisting of 100 'attr_bool' elements ('genes')
    # Number of optimization passes applied
    toolbox.register("individual", tools.initRepeat, creator.Individual,
        toolbox.attr_bool, 10)

    # define the population to be a list of individuals
    toolbox.register("population", tools.initRepeat, list, toolbox.individual)

    # the goal ('fitness') function to be maximized
    # Run Legup and recorde the negative cycles
    def evalOneMax(individual):
        cycle = getTime(c_code, individual)
        return -cycle,

    #----------
    # Operator registration
    #----------
    # register the goal / fitness function
    toolbox.register("evaluate", evalOneMax)

    # register the crossover operator
    toolbox.register("mate", tools.cxTwoPoint)

    # register a mutation operator with a probability to
    # flip each attribute/gene of 0.05
    toolbox.register("mutate", tools.mutFlipBit, indpb=0.1)

    # operator for selecting individuals for breeding the next
    # generation: each individual of the current generation
    # is replaced by the 'fittest' (best) of three individuals
    # drawn randomly from the current generation.
    # Pick top 3
    toolbox.register("select", tools.selTournament, tournsize=5)
    return toolbox
    #----------

def trainGA(toolbox):
    random.seed(64)

    # create an initial population of 300 individuals (where
    # each individual is a list of integers)
    pop = toolbox.population(n=300)

    # CXPB  is the probability with which two individuals
    #       are crossed
    #
    # MUTPB is the probability for mutating an individual
    #CXPB, MUTPB = 0.5, 0.2
    CXPB, MUTPB = 0.6, 0.3

    print("Start of evolution")

    # Evaluate the entire population
    fitnesses = list(map(toolbox.evaluate, pop))
    for ind, fit in zip(pop, fitnesses):
        ind.fitness.values = fit

    print("  Evaluated %i individuals" % len(pop))

    # Extracting all the fitnesses of
    fits = [ind.fitness.values[0] for ind in pop]

    # Variable keeping track of the number of generations
    g = 0

    # Begin the evolution
    # If the best gnome is larger than 0?
    while max(fits) < 0 and g < 30:
        # A new generation
        g = g + 1
        print("-- Generation %i --" % g)

        # Select the next generation individuals
        offspring = toolbox.select(pop, len(pop))
        # Clone the selected individuals
        offspring = list(map(toolbox.clone, offspring))

        # Apply crossover and mutation on the offspring
        for child1, child2 in zip(offspring[::2], offspring[1::2]):

            # cross two individuals with probability CXPB
            if random.random() < CXPB:
                toolbox.mate(child1, child2)

                # fitness values of the children
                # must be recalculated later
                del child1.fitness.values
                del child2.fitness.values

        for mutant in offspring:

            # mutate an individual with probability MUTPB
            if random.random() < MUTPB:
                toolbox.mutate(mutant)
                del mutant.fitness.values

        # Evaluate the individuals with an invalid fitness
        invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
        fitnesses = map(toolbox.evaluate, invalid_ind)
        for ind, fit in zip(invalid_ind, fitnesses):
            ind.fitness.values = fit

        print("  Evaluated %i individuals" % len(invalid_ind))

        # The population is entirely replaced by the offspring
        pop[:] = offspring

        # Gather all the fitnesses in one list and print the stats
        fits = [ind.fitness.values[0] for ind in pop]

        length = len(pop)
        mean = sum(fits) / length
        sum2 = sum(x*x for x in fits)
        std = abs(sum2 / length - mean**2)**0.5

        print("  Min %s" % min(fits))
        print("  Max %s" % max(fits))
        print("  Avg %s" % mean)
        print("  Std %s" % std)

    print("-- End of (successful) evolution --")

    best_ind = tools.selBest(pop, 1)[0]
    print("Best individual is %s, %s" % (best_ind, best_ind.fitness.values))
    print("Best is %s, %s" % (getcycle.getPasses(best_ind), best_ind.fitness.values))

# %%
pgms = ['benchmarks/polybench-c-3.2/linear-algebra/kernels/gemm/gemm.c']
print (pgms)
# Out:
# ['benchmarks/polybench-c-3.2/linear-algebra/kernels/gemm/gemm.c']

# %%
for pgm in pgms: 
    # Copy to skeleton folder 
    toolbox = setupGA(pgm)
    begin = time.time()
    trainGA(toolbox)
    end = time.time()
    print("Compile Time: %d"%(int(end - begin)))
# Out:
# Start of evolution
# applying 121/147 scalarizer Scalarize vector operations
# applying 31/147 dse Dead Store Elimination
# applying 103/147 nary-reassociate Nary reassociation
# applying 137/147 strip-gc-relocates Strip gc.relocates inserted through RewriteStatepointsForGC
# applying 4/147 argpromotion Promote 'by reference' arguments to scalars
# applying 52/147 instcombine Combine redundant instructions
# applying 68/147 loop-deletion Delete dead loops
# applying 51/147 inline Function Integration/Inlining
# applying 37/147 flattencfg Flatten the CFG
# applying 20/147 cost-model Cost Model Analysis
# timing function
# wall time:  6.431
# applying 106/147 pa-eval Evaluate ProvenanceAnalysis on all pairs
# applying 112/147 pre-isel-intrinsic-lowering Pre-ISel Intrinsic Lowering
# applying 50/147 inferattrs Infer set function attributes
# applying 6/147 atomic-expand Expand Atomic instructions
# applying 21/147 cross-dso-cfi Cross-DSO CFI
# applying 103/147 nary-reassociate Nary reassociation
# applying 1/147 adce Aggressive Dead Code Elimination
# applying 16/147 codegenprepare Optimize for code generation
# applying 44/147 globalsplit Global splitter
# applying 26/147 demanded-bits Demanded bits analysis
# timing function
# wall time:  6.394
# applying 11/147 branch-prob Branch Probability Analysis
# applying 67/147 loop-data-prefetch Loop Data Prefetch
# applying 56/147 ipconstprop Interprocedural constant propagation
# applying 138/147 strip-nondebug Strip all symbols, except dbg symbols, from a module
# applying 50/147 inferattrs Infer set function attributes
# applying 22/147 da Dependence Analysis
# applying 7/147 basicaa Basic Alias Analysis (stateless AA impl)
# applying 117/147 rewrite-statepoints-for-gc Make relocations explicit at statepoints
# applying 101/147 mergereturn Unify function exit nodes
# applying 54/147 interleaved-access Lower interleaved memory accesses to target specific intrinsics
# timing function
# wall time:  6.453
# applying 75/147 loop-load-elim Loop Load Elimination
# applying 35/147 expand-reductions Expand reduction intrinsics
# applying 140/147 structurizecfg Structurize the CFG
# applying 109/147 place-backedge-safepoints-impl Place Backedge Safepoints
# applying 91/147 loweratomic Lower atomic intrinsics to non-atomic form
# applying 130/147 slsr Straight line strength reduction
# applying 78/147 loop-reroll Reroll loops
# applying 93/147 lowerswitch Lower SwitchInst's to branches
# applying 124/147 scoped-noalias Scoped NoAlias Alias Analysis
# applying 132/147 sroa Scalar Replacement Of Aggregates
# timing function
# wall time:  6.202
# applying 45/147 gvn Global Value Numbering
# applying 12/147 break-crit-edges Break critical edges in CFG
# applying 0/147 aa Function Alias Analysis Results
# applying 59/147 iv-users Induction Variable Users
# applying 119/147 scalar-evolution Scalar Evolution Analysis
# applying 41/147 globaldce Dead Global Elimination
# applying 54/147 interleaved-access Lower interleaved memory accesses to target specific intrinsics
# applying 56/147 ipconstprop Interprocedural constant propagation
# applying 14/147 cfl-anders-aa Inclusion-Based CFL Alias Analysis
# applying 71/147 loop-extract-single Extract at most one loop into a new function
# timing function
# wall time:  6.215
# applying 55/147 intervals Interval Partition Construction
# applying 62/147 lcssa Loop-Closed SSA Form Pass
# applying 7/147 basicaa Basic Alias Analysis (stateless AA impl)
# applying 77/147 loop-reduce Loop Strength Reduction
# applying 28/147 divergence Divergence Analysis
# applying 40/147 global-merge Merge global variables
# applying 76/147 loop-predication Loop predication
# applying 57/147 ipsccp Interprocedural Sparse Conditional Constant Propagation
# applying 145/147 unreachableblockelim Remove unreachable blocks from the CFG
# applying 60/147 jump-threading Jump Threading
# timing function
# wall time:  6.538
# applying 62/147 lcssa Loop-Closed SSA Form Pass
# applying 38/147 float2int Float to int
# applying 66/147 loop-accesses Loop Access Analysis
# applying 108/147 partially-inline-libcalls Partially inline calls to library functions
# applying 113/147 prune-eh Remove unused exception handling info
# applying 76/147 loop-predication Loop predication
# applying 95/147 machine-branch-prob Machine Branch Probability Analysis
# applying 43/147 globals-aa Globals Alias Analysis
# applying 70/147 loop-extract Extract loops into new functions
# applying 39/147 forceattrs Force set function attributes
# timing function
# wall time:  6.448
# applying 45/147 gvn Global Value Numbering
# applying 76/147 loop-predication Loop predication
# applying 11/147 branch-prob Branch Probability Analysis
# applying 32/147 early-cse Early CSE
# applying 13/147 cfinserter Inserts calls to mcount-like functions
# applying 28/147 divergence Divergence Analysis
# applying 30/147 domtree Dominator Tree Construction
# applying 130/147 slsr Straight line strength reduction
# applying 14/147 cfl-anders-aa Inclusion-Based CFL Alias Analysis
# applying 43/147 globals-aa Globals Alias Analysis
# timing function
# wall time:  6.239
# applying 85/147 loop-vectorize Loop Vectorization
# applying 143/147 tbaa Type-Based Alias Analysis
# applying 64/147 licm Loop Invariant Code Motion
# applying 108/147 partially-inline-libcalls Partially inline calls to library functions
# applying 121/147 scalarizer Scalarize vector operations
# applying 11/147 branch-prob Branch Probability Analysis
# applying 126/147 simple-loop-unswitch Simple unswitch loops
# applying 81/147 loop-simplifycfg Simplify loop CFG
# applying 131/147 speculative-execution Speculatively execute instructions
# applying 9/147 bdce Bit-Tracking Dead Code Elimination
# timing function
# wall time:  6.252
# applying 13/147 cfinserter Inserts calls to mcount-like functions
# applying 137/147 strip-gc-relocates Strip gc.relocates inserted through RewriteStatepointsForGC
# applying 80/147 loop-simplify Canonicalize natural loops
# applying 36/147 external-aa External Alias Analysis
# applying 27/147 die Dead Instruction Elimination
# applying 128/147 sink Code sinking
# applying 84/147 loop-unswitch Unswitch loops
# applying 78/147 loop-reroll Reroll loops
# applying 129/147 slp-vectorizer SLP Vectorizer
# applying 32/147 early-cse Early CSE
# timing function
# wall time:  6.475
# applying 100/147 mergefunc Merge Functions
# applying 99/147 memoryssa Memory SSA
# applying 95/147 machine-branch-prob Machine Branch Probability Analysis
# applying 34/147 elim-avail-extern Eliminate Available Externally Globals
# applying 83/147 loop-unroll Unroll loops
# applying 106/147 pa-eval Evaluate ProvenanceAnalysis on all pairs
# applying 2/147 alignment-from-assumptions Alignment from assumptions
# applying 2/147 alignment-from-assumptions Alignment from assumptions
# applying 79/147 loop-rotate Rotate Loops
# applying 43/147 globals-aa Globals Alias Analysis
# timing function
# wall time:  6.291
# applying 97/147 memcpyopt MemCpy Optimization
# applying 47/147 gvn-sink Early GVN sinking of Expressions
# applying 135/147 strip-dead-prototypes Strip Unused Function Prototypes
# applying 58/147 irce Inductive range check elimination
# applying 121/147 scalarizer Scalarize vector operations
# applying 71/147 loop-extract-single Extract at most one loop into a new function
# applying 144/147 tti Target Transform Information
# applying 114/147 reassociate Reassociate expressions
# applying 21/147 cross-dso-cfi Cross-DSO CFI
# applying 81/147 loop-simplifycfg Simplify loop CFG
# timing function
# wall time:  6.397
# applying 76/147 loop-predication Loop predication
# applying 65/147 load-store-vectorizer Vectorize load and store instructions
# applying 6/147 atomic-expand Expand Atomic instructions
# applying 108/147 partially-inline-libcalls Partially inline calls to library functions
# applying 92/147 lowerinvoke Lower invoke and unwind, for unwindless code generators
# applying 26/147 demanded-bits Demanded bits analysis
# applying 31/147 dse Dead Store Elimination
# applying 120/147 scalarize-masked-mem-intrin Scalarize unsupported masked memory intrinsics
# applying 92/147 lowerinvoke Lower invoke and unwind, for unwindless code generators
# applying 124/147 scoped-noalias Scoped NoAlias Alias Analysis
# timing function
# wall time:  6.315
# applying 24/147 deadargelim Dead Argument Elimination
# applying 11/147 branch-prob Branch Probability Analysis
# applying 136/147 strip-debug-declare Strip all llvm.dbg.declare intrinsics
# applying 131/147 speculative-execution Speculatively execute instructions
# applying 23/147 dce Dead Code Elimination
# applying 5/147 assumption-cache-tracker Assumption Cache Tracker
# applying 128/147 sink Code sinking
# applying 31/147 dse Dead Store Elimination
# applying 104/147 newgvn Global Value Numbering
# applying 96/147 mem2reg Promote Memory to Register
# timing function
# wall time:  6.232
# applying 29/147 domfrontier Dominance Frontier Construction
# applying 98/147 memdep Memory Dependence Analysis
# applying 41/147 globaldce Dead Global Elimination
# applying 134/147 strip-dead-debug-info Strip debug info for unused symbols
# applying 39/147 forceattrs Force set function attributes
# applying 75/147 loop-load-elim Loop Load Elimination
# applying 89/147 lower-expect Lower 'expect' Intrinsics
# applying 144/147 tti Target Transform Information
# applying 31/147 dse Dead Store Elimination
# applying 53/147 instsimplify Remove redundant instructions
# timing function
# wall time:  6.47
# applying 0/147 aa Function Alias Analysis Results
# applying 85/147 loop-vectorize Loop Vectorization
# applying 57/147 ipsccp Interprocedural Sparse Conditional Constant Propagation
# applying 38/147 float2int Float to int
# applying 98/147 memdep Memory Dependence Analysis
# applying 21/147 cross-dso-cfi Cross-DSO CFI
# applying 52/147 instcombine Combine redundant instructions
# applying 135/147 strip-dead-prototypes Strip Unused Function Prototypes
# applying 107/147 partial-inliner Partial Inliner
# applying 35/147 expand-reductions Expand reduction intrinsics
# timing function
# wall time:  6.21
# applying 1/147 adce Aggressive Dead Code Elimination
# applying 72/147 loop-idiom Recognize loop idioms
# applying 79/147 loop-rotate Rotate Loops
# applying 105/147 opt-remark-emitter Optimization Remark Emitter
# applying 34/147 elim-avail-extern Eliminate Available Externally Globals
# applying 120/147 scalarize-masked-mem-intrin Scalarize unsupported masked memory intrinsics
# applying 6/147 atomic-expand Expand Atomic instructions
# applying 80/147 loop-simplify Canonicalize natural loops
# applying 131/147 speculative-execution Speculatively execute instructions
# applying 70/147 loop-extract Extract loops into new functions
# timing function
# wall time:  6.229
# applying 108/147 partially-inline-libcalls Partially inline calls to library functions
# applying 116/147 regions Detect single entry single exit regions
# applying 84/147 loop-unswitch Unswitch loops
# applying 35/147 expand-reductions Expand reduction intrinsics
# applying 52/147 instcombine Combine redundant instructions
# applying 137/147 strip-gc-relocates Strip gc.relocates inserted through RewriteStatepointsForGC
# applying 53/147 instsimplify Remove redundant instructions
# applying 86/147 loop-versioning Loop Versioning
# applying 66/147 loop-accesses Loop Access Analysis
# applying 142/147 targetlibinfo Target Library Information
# timing function
# wall time:  6.148
# applying 44/147 globalsplit Global splitter
# applying 124/147 scoped-noalias Scoped NoAlias Alias Analysis
# applying 8/147 basiccg CallGraph Construction
# applying 47/147 gvn-sink Early GVN sinking of Expressions
# applying 2/147 alignment-from-assumptions Alignment from assumptions
# applying 85/147 loop-vectorize Loop Vectorization
# applying 84/147 loop-unswitch Unswitch loops
# applying 42/147 globalopt Global Variable Optimizer
# applying 52/147 instcombine Combine redundant instructions
# applying 74/147 loop-interchange Interchanges loops for cache reuse
# timing function
# wall time:  6.241
